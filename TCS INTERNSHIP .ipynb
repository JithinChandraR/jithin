# %% [markdown]
# # CLASSIFICATION MODEL FOR SIDE EFFECTS OF A DRUG

# %% [markdown]
# #

# %% [markdown]
# A side effect is usually regarded as an undesirable secondary effect which occurs in addition to the desired therapeutic effect of a drug or medication. Side effects may vary for each individual depending on the person's disease state, age, weight, gender, ethnicity and general health.
# The objective of this project is to build a classification model that classifies the side effects of a particular drug by age,gender,and race.

# %%
#importing required libraries

import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
from faker import Faker
from random import randrange
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,precision_score,recall_score,f1_score
import warnings
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")
import string
import spacy
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS as sklearn_stop_words
import pickle

# %%
# Loading dataset

data1 = pd.read_csv(r"C:\Users\chand\OneDrive\Desktop\tcs\webmd.csv")
data1.head(5)
# Out:
#           Age      Condition       Date                          Drug  DrugId  \
# 0  75 or over    Stuffy Nose  9/21/2014                  25dph-7.5peh  146724
# 1       25-34  Cold Symptoms  1/13/2011                  25dph-7.5peh  146724
# 2       65-74          Other  7/16/2012  warfarin (bulk) 100 % powder  144731
# 3  75 or over          Other  9/23/2010  warfarin (bulk) 100 % powder  144731
# 4       35-44          Other   1/6/2009  warfarin (bulk) 100 % powder  144731
#
#    EaseofUse  Effectiveness  \
# 0          5              5
# 1          5              5
# 2          2              3
# 3          2              2
# 4          1              1
#
#                                              Reviews  Satisfaction     Sex  \
# 0  I'm a retired physician and of all the meds I ...             5    Male
# 1  cleared me right up even with my throat hurtin...             5  Female
# 2  why did my PTINR go from a normal of 2.5 to ov...             3  Female
# 3                       FALLING AND DON'T REALISE IT             1  Female
# 4  My grandfather was prescribed this medication ...             1    Male
#
#                                                Sides  UsefulCount
# 0  Drowsiness,  dizziness ,  dry mouth /nose/thro...            0
# 1  Drowsiness,  dizziness ,  dry mouth /nose/thro...            1
# 2                                                               0
# 3                                                               0
# 4                                                               1

# %%
# Checking the dimension of the dataset

data1.shape
# Out:
# (362806, 12)

# %% [markdown]
# Since we are expected to create a dataset of 4,00,000 patients.we are going to add some fake data using faker.

# %%
no_customers = 40000
fake = Faker('de_DE')
customers = []

# %%
for customers_id in range(no_customers):
    Age = random.choice(["55-64","55-64","65-74","45-54"])
    Condition = random.choice(["Other","Pain","High Blood Pressure","Depression","Birth Control"])
    d1 = datetime.strptime(f'1/1/2004', '%m/%d/%Y')
    d2 = datetime.strptime(f'8/10/2014', '%m/%d/%Y')
    Date = fake.date_between(d1, d2)
    Drug = random.choice(["cymbalta","lisinopril","lisinopril solution","celexa","lyrica","chantix","lexapro","midol complete","minocycline hcl",
                          "hydrocodone-acetaminophen","cabergoline","phentermine hcl","metformin hcl","metadate cd","microgestin"])
    DrugId = random.randint(147700,158800)
    EaseofUse = random.randint(2,5)
    Effectiveness = random.randint(1,5)
    Reviews = random.choice(["good ","good ","good ","good ","good","good ","good","this treatment is awsome.  I love drugs.","This drug is awesome.  I love drugs."])
    Satisfaction = random.randint(1,5)
    Sex = random.choice(["Male", "Female"])
    Sides = random.choice(["Nausea ,  dry mouth ,  constipation ","Nausea ,  vomiting ,  constipation ,  lightheadedness",
                           "Drowsiness,  dizziness","Dizziness ,  lightheadedness , tiredness, or  headache","Dizziness ,  lightheadedness , tiredness"])
    UsefulCount =  random.randint(0,16)
    customers.append([Age,Condition,Date,Drug,DrugId,EaseofUse,Effectiveness,Reviews,Satisfaction,Sex,Sides,UsefulCount])
    
data2 = pd.DataFrame(customers, columns=['Age','Condition','Date','Drug','DrugId','EaseofUse','Effectiveness','Reviews','Satisfaction','Sex','Sides','UsefulCount']) 
data2
# Out:
#          Age            Condition        Date                       Drug  \
# 0      55-64           Depression  2013-04-13              metformin hcl
# 1      65-74                 Pain  2006-02-11                microgestin
# 2      65-74                Other  2005-12-30                     lyrica
# 3      45-54        Birth Control  2005-04-25  hydrocodone-acetaminophen
# 4      55-64           Depression  2008-05-18                     celexa
# ...      ...                  ...         ...                        ...
# 39995  55-64                 Pain  2006-01-29                    lexapro
# 39996  55-64                 Pain  2007-03-03  hydrocodone-acetaminophen
# 39997  45-54  High Blood Pressure  2011-04-12                     celexa
# 39998  65-74  High Blood Pressure  2007-02-28              metformin hcl
# 39999  55-64  High Blood Pressure  2006-03-20        lisinopril solution
#
#        DrugId  EaseofUse  Effectiveness  \
# 0      151179          4              5
# 1      155297          3              3
# 2      149150          2              1
# 3      152307          4              5
# 4      152645          4              2
# ...       ...        ...            ...
# 39995  149022          3              2
# 39996  155522          3              1
# 39997  152895          2              2
# 39998  158680          3              3
# 39999  152091          3              4
#
#                                         Reviews  Satisfaction     Sex  \
# 0                                         good              5  Female
# 1          This drug is awesome.  I love drugs.             5  Female
# 2                                         good              5    Male
# 3                                         good              3    Male
# 4                                         good              4    Male
# ...                                         ...           ...     ...
# 39995                                     good              2  Female
# 39996                                     good              4  Female
# 39997  this treatment is awsome.  I love drugs.             5    Male
# 39998                                      good             4    Male
# 39999                                     good              1    Male
#
#                                                    Sides  UsefulCount
# 0               Dizziness ,  lightheadedness , tiredness            3
# 1               Dizziness ,  lightheadedness , tiredness            1
# 2                   Nausea ,  dry mouth ,  constipation             1
# 3                   Nausea ,  dry mouth ,  constipation            13
# 4               Dizziness ,  lightheadedness , tiredness            5
# ...                                                  ...          ...
# 39995  Dizziness ,  lightheadedness , tiredness, or  ...            4
# 39996  Nausea ,  vomiting ,  constipation ,  lighthea...           12
# 39997  Dizziness ,  lightheadedness , tiredness, or  ...            9
# 39998  Nausea ,  vomiting ,  constipation ,  lighthea...            0
# 39999               Nausea ,  dry mouth ,  constipation            11
#
# [40000 rows x 12 columns]

# %%
# dimension of created dataset
data2.shape
# Out:
# (40000, 12)

# %%
# Connecting orginal dataset and created dataset

data3 = pd.concat([data1, data2],axis=0,ignore_index=True)
data3.head()
# Out:
#           Age      Condition       Date                          Drug  DrugId  \
# 0  75 or over    Stuffy Nose  9/21/2014                  25dph-7.5peh  146724
# 1       25-34  Cold Symptoms  1/13/2011                  25dph-7.5peh  146724
# 2       65-74          Other  7/16/2012  warfarin (bulk) 100 % powder  144731
# 3  75 or over          Other  9/23/2010  warfarin (bulk) 100 % powder  144731
# 4       35-44          Other   1/6/2009  warfarin (bulk) 100 % powder  144731
#
#    EaseofUse  Effectiveness  \
# 0          5              5
# 1          5              5
# 2          2              3
# 3          2              2
# 4          1              1
#
#                                              Reviews  Satisfaction     Sex  \
# 0  I'm a retired physician and of all the meds I ...             5    Male
# 1  cleared me right up even with my throat hurtin...             5  Female
# 2  why did my PTINR go from a normal of 2.5 to ov...             3  Female
# 3                       FALLING AND DON'T REALISE IT             1  Female
# 4  My grandfather was prescribed this medication ...             1    Male
#
#                                                Sides  UsefulCount
# 0  Drowsiness,  dizziness ,  dry mouth /nose/thro...            0
# 1  Drowsiness,  dizziness ,  dry mouth /nose/thro...            1
# 2                                                               0
# 3                                                               0
# 4                                                               1

# %%
# Dimension of New dataset
data3.shape
# Out:
# (402806, 12)

# %% [markdown]
# # Name and Race column addition

# %%
pip install mimesis
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mimesis in c:\users\chand\appdata\roaming\python\python39\site-packages (10.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from mimesis import Person
person = Person('en')

# defining function to create names for each rows

def fake_names(n):
   name = []
   for _ in range(0, n):
        name.append(person.name())
   return name

names = fake_names(402806)

data_name = pd.DataFrame(list(zip(names)),columns = ['Name'])

# %%
# Creating race columns 

options = [("White", 0.32), ("Hispanic", 0.28), ("Black", 0.22), ("Asian", 0.18)]
words = []

for i in range(402806):
    word = random.choices([o[0] for o in options], [o[1] for o in options])[0]
    words.append(word)

data_race=pd.DataFrame(words, columns = ['Race'])

# %%
# Adding race and name columnto the data_set

data = pd.concat([data_name, data_race, data3], axis=1).reindex(data3.index)
data.head(5)
# Out:
#       Name      Race         Age      Condition       Date  \
# 0  Marilou  Hispanic  75 or over    Stuffy Nose  9/21/2014
# 1   Melvin     Black       25-34  Cold Symptoms  1/13/2011
# 2    Gayle  Hispanic       65-74          Other  7/16/2012
# 3       Ty     White  75 or over          Other  9/23/2010
# 4      Jae  Hispanic       35-44          Other   1/6/2009
#
#                            Drug  DrugId  EaseofUse  Effectiveness  \
# 0                  25dph-7.5peh  146724          5              5
# 1                  25dph-7.5peh  146724          5              5
# 2  warfarin (bulk) 100 % powder  144731          2              3
# 3  warfarin (bulk) 100 % powder  144731          2              2
# 4  warfarin (bulk) 100 % powder  144731          1              1
#
#                                              Reviews  Satisfaction     Sex  \
# 0  I'm a retired physician and of all the meds I ...             5    Male
# 1  cleared me right up even with my throat hurtin...             5  Female
# 2  why did my PTINR go from a normal of 2.5 to ov...             3  Female
# 3                       FALLING AND DON'T REALISE IT             1  Female
# 4  My grandfather was prescribed this medication ...             1    Male
#
#                                                Sides  UsefulCount
# 0  Drowsiness,  dizziness ,  dry mouth /nose/thro...            0
# 1  Drowsiness,  dizziness ,  dry mouth /nose/thro...            1
# 2                                                               0
# 3                                                               0
# 4                                                               1

# %%
# Dimension of Final data set
data.shape
# Out:
# (402806, 14)

# %% [markdown]
# # Dataset is  now ready for EDA and Preprocessing

# %%
# Basic data exploration

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402806 entries, 0 to 402805
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Name           402806 non-null  object
#  1   Race           402806 non-null  object
#  2   Age            402806 non-null  object
#  3   Condition      402806 non-null  object
#  4   Date           402806 non-null  object
#  5   Drug           402806 non-null  object
#  6   DrugId         402806 non-null  int64
#  7   EaseofUse      402806 non-null  int64
#  8   Effectiveness  402806 non-null  int64
#  9   Reviews        402769 non-null  object
#  10  Satisfaction   402806 non-null  int64
#  11  Sex            402806 non-null  object
#  12  Sides          402806 non-null  object
#  13  UsefulCount    402806 non-null  int64
# dtypes: int64(5), object(9)
# memory usage: 43.0+ MB

# %%
data["Satisfaction"] = data["Satisfaction"].astype(int)

# %%
data.describe()
# Out:
#               DrugId      EaseofUse  Effectiveness   Satisfaction  \
# count  402806.000000  402806.000000  402806.000000  402806.000000
# mean    48434.370819       3.968171       3.478441       3.121696
# std     60880.035710       1.308173       1.461206       1.592990
# min         1.000000       1.000000       1.000000       1.000000
# 25%      5219.000000       3.000000       2.000000       1.000000
# 50%     11285.000000       5.000000       4.000000       3.000000
# 75%     91515.000000       5.000000       5.000000       5.000000
# max    178546.000000      10.000000      10.000000      10.000000
#
#          UsefulCount
# count  402806.000000
# mean        6.870950
# std         8.990956
# min         0.000000
# 25%         1.000000
# 50%         4.000000
# 75%        10.000000
# max       255.000000

# %%
data.nunique()
# Out:
# Name               3323
# Race                  4
# Age                  12
# Condition          1806
# Date               8398
# Drug               7093
# DrugId            16191
# EaseofUse             7
# Effectiveness         7
# Reviews          250167
# Satisfaction          7
# Sex                   3
# Sides              1656
# UsefulCount         148
# dtype: int64

# %% [markdown]
#  Generating Year column

# %%
data['Year'] = pd.to_datetime(data['Date'], errors='coerce').dt.year

# %%
data.head(5)
# Out:
#       Name      Race         Age      Condition       Date  \
# 0  Marilou  Hispanic  75 or over    Stuffy Nose  9/21/2014
# 1   Melvin     Black       25-34  Cold Symptoms  1/13/2011
# 2    Gayle  Hispanic       65-74          Other  7/16/2012
# 3       Ty     White  75 or over          Other  9/23/2010
# 4      Jae  Hispanic       35-44          Other   1/6/2009
#
#                            Drug  DrugId  EaseofUse  Effectiveness  \
# 0                  25dph-7.5peh  146724          5              5
# 1                  25dph-7.5peh  146724          5              5
# 2  warfarin (bulk) 100 % powder  144731          2              3
# 3  warfarin (bulk) 100 % powder  144731          2              2
# 4  warfarin (bulk) 100 % powder  144731          1              1
#
#                                              Reviews  Satisfaction     Sex  \
# 0  I'm a retired physician and of all the meds I ...             5    Male
# 1  cleared me right up even with my throat hurtin...             5  Female
# 2  why did my PTINR go from a normal of 2.5 to ov...             3  Female
# 3                       FALLING AND DON'T REALISE IT             1  Female
# 4  My grandfather was prescribed this medication ...             1    Male
#
#                                                Sides  UsefulCount  Year
# 0  Drowsiness,  dizziness ,  dry mouth /nose/thro...            0  2014
# 1  Drowsiness,  dizziness ,  dry mouth /nose/thro...            1  2011
# 2                                                               0  2012
# 3                                                               0  2010
# 4                                                               1  2009

# %%
# Checking null values

data.isna().sum()
# Out:
# Name              0
# Race              0
# Age               0
# Condition         0
# Date              0
# Drug              0
# DrugId            0
# EaseofUse         0
# Effectiveness     0
# Reviews          37
# Satisfaction      0
# Sex               0
# Sides             0
# UsefulCount       0
# Year              0
# dtype: int64

# %% [markdown]
# ## Number of reviews collected in each year

# %%
# Basic univariate and bivariate analysis

# %%
data['Year'].value_counts().plot(kind='bar')
plt.title("Year", fontsize = 10)
plt.xlabel("Year", fontsize = 10)
plt.ylabel("Count of Reviews", fontsize = 10)
plt.show()

# %% [markdown]
# The year 2009 tops the list and there is a gradual decrease in user reviews

# %% [markdown]
# ## Top 20 Drugs based on No. of Users

# %%
data_= data['Drug'].value_counts().head(20).reset_index()
data_.columns = ['Drug', 'Name']
sns.barplot(data=data_, x = 'Drug', y = 'Name')
plt.suptitle("Top 20 Drugs")
plt.xticks(rotation=90,fontsize=10)
plt.show()

# %% [markdown]
# Cymbalta drug tops the list followed by Lisinopril.All the top 20 drugs has been used by more than 2000 people

# %% [markdown]
# ## Top 15 Conditions

# %%
data['Condition'].value_counts().nlargest(20).plot(kind='bar',figsize=(8,8))
plt.suptitle("Top 15 Conditions")
plt.xlabel('Conditions')
plt.ylabel('Users')
plt.show()

# %% [markdown]
# More than 50,000 users have reported other conditions followed by Pain and
# High blood pressure are topped the list with more than 30000 people reporting it.Also nearly 22,000 user's have reported depression.

# %% [markdown]
# ## Side effects and Drug

# %%
plt.figure(figsize=(20, 15))
sns.countplot(x='Drug',hue='Sides',data=data2)
plt.xticks(rotation=90,fontsize=10)
plt.show()

# %% [markdown]
# Almost all the drug have reported extreme side effects.Most of the drugs having more than 500 counts for each side effects.

# %% [markdown]
# ## From the above charts,A drug named Lisinopril Solution is selected for building a classification model to determine side effects.

# %%
ldata=data[data.Drug == "lisinopril solution"]
ldata.head(5)
# Out:
#         Name      Race         Age            Condition        Date  \
# 9197     Jon     Black              High Blood Pressure   2/29/2020
# 9203  Hector     Asian  75 or over  High Blood Pressure    2/8/2020
# 9209  Donnie  Hispanic       55-64  High Blood Pressure   1/14/2020
# 9215  Indira     Black       65-74  High Blood Pressure  10/17/2019
# 9221     Dee     White       55-64  High Blood Pressure  10/13/2019
#
#                      Drug  DrugId  EaseofUse  Effectiveness  \
# 9197  lisinopril solution    6873          5              5
# 9203  lisinopril solution    6873          5              4
# 9209  lisinopril solution    6873          4              5
# 9215  lisinopril solution    6873          5              5
# 9221  lisinopril solution    6873          2              4
#
#                                                 Reviews  Satisfaction     Sex  \
# 9197  No Script or health Insurance needed to place ...             5
# 9203  I have developed a very itch rash on my body f...             4  Female
# 9209  tried alternative medicine Beet root, hibiscus...             4    Male
# 9215  Have been taking 10 mg doses per day for over ...             5    Male
# 9221  I don't like that I'm taking this and not know...             2    Male
#
#                                                   Sides  UsefulCount  Year
# 9197  Dizziness ,  lightheadedness , tiredness, or  ...           14  2020
# 9203  Dizziness ,  lightheadedness , tiredness, or  ...            3  2020
# 9209  Dizziness ,  lightheadedness , tiredness, or  ...            3  2020
# 9215  Dizziness ,  lightheadedness , tiredness, or  ...            6  2019
# 9221  Dizziness ,  lightheadedness , tiredness, or  ...           12  2019

# %% [markdown]
# ## EDA on LICINOPRIL SOLUTION

# %%
ldata.shape
# Out:
# (7024, 15)

# %%
# drop duplicated row
ldata.drop_duplicates(inplace=True, keep='first')

# %%
# Missing Value Handling
ldata.isna().sum()
# Out:
# Name             0
# Race             0
# Age              0
# Condition        0
# Date             0
# Drug             0
# DrugId           0
# EaseofUse        0
# Effectiveness    0
# Reviews          2
# Satisfaction     0
# Sex              0
# Sides            0
# UsefulCount      0
# Year             0
# dtype: int64

# %%
# Nan rows were dropped
ldata.dropna(axis = 0, inplace = True)
ldata.isna().sum()
# Out:
# Name             0
# Race             0
# Age              0
# Condition        0
# Date             0
# Drug             0
# DrugId           0
# EaseofUse        0
# Effectiveness    0
# Reviews          0
# Satisfaction     0
# Sex              0
# Sides            0
# UsefulCount      0
# Year             0
# dtype: int64

# %%
# Handling instances with whitespaces
for i in ldata:
    ldata[i]=np.where(ldata[i]==" ",np.NAN,ldata[i])
    
ldata.isna().sum()
# Out:
# Name               0
# Race               0
# Age              135
# Condition          0
# Date               0
# Drug               0
# DrugId             0
# EaseofUse          0
# Effectiveness      0
# Reviews          781
# Satisfaction       0
# Sex              247
# Sides              0
# UsefulCount        0
# Year               0
# dtype: int64

# %%
ldata.dropna(axis=0, inplace = True)
ldata.isna().sum()
# Out:
# Name             0
# Race             0
# Age              0
# Condition        0
# Date             0
# Drug             0
# DrugId           0
# EaseofUse        0
# Effectiveness    0
# Reviews          0
# Satisfaction     0
# Sex              0
# Sides            0
# UsefulCount      0
# Year             0
# dtype: int64

# %%
# Handling instances with double whitespaces
for i in ldata:
    ldata[i]=np.where(ldata[i]=="  ",np.NAN,ldata[i])
    
ldata.isna().sum()
# Out:
# Name             0
# Race             0
# Age              0
# Condition        0
# Date             0
# Drug             0
# DrugId           0
# EaseofUse        0
# Effectiveness    0
# Reviews          0
# Satisfaction     0
# Sex              0
# Sides            0
# UsefulCount      0
# Year             0
# dtype: int64

# %%
ldata.head(5)
# Out:
#          Name      Race         Age            Condition        Date  \
# 9203   Hector     Asian  75 or over  High Blood Pressure    2/8/2020
# 9209   Donnie  Hispanic       55-64  High Blood Pressure   1/14/2020
# 9215   Indira     Black       65-74  High Blood Pressure  10/17/2019
# 9221      Dee     White       55-64  High Blood Pressure  10/13/2019
# 9227  Florrie  Hispanic       55-64  High Blood Pressure   8/16/2019
#
#                      Drug  DrugId  EaseofUse  Effectiveness  \
# 9203  lisinopril solution  6873.0        5.0            4.0
# 9209  lisinopril solution  6873.0        4.0            5.0
# 9215  lisinopril solution  6873.0        5.0            5.0
# 9221  lisinopril solution  6873.0        2.0            4.0
# 9227  lisinopril solution  6873.0        3.0            1.0
#
#                                                 Reviews  Satisfaction     Sex  \
# 9203  I have developed a very itch rash on my body f...           4.0  Female
# 9209  tried alternative medicine Beet root, hibiscus...           4.0    Male
# 9215  Have been taking 10 mg doses per day for over ...           5.0    Male
# 9221  I don't like that I'm taking this and not know...           2.0    Male
# 9227  Was on this medicine for about 2 months and ha...           1.0  Female
#
#                                                   Sides  UsefulCount    Year
# 9203  Dizziness ,  lightheadedness , tiredness, or  ...          3.0  2020.0
# 9209  Dizziness ,  lightheadedness , tiredness, or  ...          3.0  2020.0
# 9215  Dizziness ,  lightheadedness , tiredness, or  ...          6.0  2019.0
# 9221  Dizziness ,  lightheadedness , tiredness, or  ...         12.0  2019.0
# 9227  Dizziness ,  lightheadedness , tiredness, or  ...         22.0  2019.0

# %% [markdown]
# checking each columns and unique values

# %%
ldata.Sex.value_counts()
# Out:
# Female    3440
# Male      2578
# Name: Sex, dtype: int64

# %%
ldata.Age.value_counts()
# Out:
# 55-64         2372
# 45-54         1529
# 65-74         1264
# 35-44          429
# 75 or over     245
# 25-34          153
# 19-24           22
# 13-18            3
# 0-2              1
# Name: Age, dtype: int64

# %%
ldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6018 entries, 9203 to 402805
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           6018 non-null   object
#  1   Race           6018 non-null   object
#  2   Age            6018 non-null   object
#  3   Condition      6018 non-null   object
#  4   Date           6018 non-null   object
#  5   Drug           6018 non-null   object
#  6   DrugId         6018 non-null   float64
#  7   EaseofUse      6018 non-null   float64
#  8   Effectiveness  6018 non-null   float64
#  9   Reviews        6018 non-null   object
#  10  Satisfaction   6018 non-null   float64
#  11  Sex            6018 non-null   object
#  12  Sides          6018 non-null   object
#  13  UsefulCount    6018 non-null   float64
#  14  Year           6018 non-null   float64
# dtypes: float64(6), object(9)
# memory usage: 752.2+ KB

# %%
ldata.Condition.value_counts()
# Out:
# High Blood Pressure                                         3511
# Other                                                        640
# Birth Control                                                597
# Pain                                                         544
# Depression                                                   504
# Kidney Disease from Diabetes                                  83
# Heart Attack                                                  52
# Chronic Heart Failure                                         25
# Prevention of Recurrent Atrial Fibrillation                   16
# Failure of the Left Ventricle of the Heart                    13
# Migraine Prevention                                           10
# Nondiabetic Proteinuric Nephropathy                            9
# Kidney Problem caused by Body Tissue Disease-Scleroderma       8
# Diastolic Heart Failure                                        3
# Retinal Changes of Eye in a Patient with Diabetes              3
# Name: Condition, dtype: int64

# %% [markdown]
# # Plotting data relationships, Charts which give us more insight into the data

# %% [markdown]
# USERS AND GENDER

# %%
plt.figure(figsize = (4,4))
s=sns.countplot(x='Sex', data=ldata)
plt.title('Users by Gender', fontsize=15)
plt.xlabel('Sex')
plt.ylabel('Count') 
plt.show()

# %% [markdown]
# Female users are predominant in the use of Licinopril solution

# %% [markdown]
# USERS AND RACE

# %%
sns.countplot(x='Race',hue='Sex',data=ldata)
plt.title("Users by Race and Gender", fontsize = 10)
plt.show()

# %% [markdown]
# users belongs to white race is the predominant users followed by hispanic.
# In each race female gender is the predominant users.

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Age',hue='Sex',data=ldata)
plt.title("Users by Age and Gender", fontsize = 10)
plt.xticks(rotation=90,fontsize=10)
plt.show()

# %% [markdown]
# users age group 55-64 consumes more drugs followed by the age group 45-54.In each age group female gender is the predominant user,except the age group 75 or over.

# %% [markdown]
# EFFECTIVENESS OF DRUG

# %%
ldata['Effectiveness'].value_counts().plot(kind='bar')
plt.title("Effectiveness", fontsize = 10)
plt.xlabel("Effectiveness", fontsize = 10)
plt.ylabel("Count", fontsize = 10)
plt.show()

# %% [markdown]
# The drug is fairly effective with more than 1600 users voting a 4 rating and 5 rating  to it.

# %% [markdown]
# SIDE EFFECT AND DRUG

# %%
plt.figure(figsize=(10,10))
ldata['Sides'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %% [markdown]
# 61% of users reported extreme si.de effects

# %% [markdown]
# AGE AND SIDE EFFECTS

# %%
plt.figure(figsize=(20, 15))
sns.countplot(x='Age',hue='Sides',data=ldata);

# %% [markdown]
# 55-64 age group has opinionated that they had extreme side effects.

# %% [markdown]
# RACE AND SIDE EFFECT

# %%
plt.figure(figsize=(20, 15))
sns.countplot(x='Race',hue='Sides',data=ldata)
# Out:
# <AxesSubplot:xlabel='Race', ylabel='count'>

# %% [markdown]
# White and Hispanic users reported more extreme side effects

# %%
# Potting Numerical Values (UsefulCount, easeofuse, effectiveness and satisfaction )


ldata.hist(column=["EaseofUse","Effectiveness","Satisfaction","UsefulCount"],figsize=(20,15))
plt.show()

# %%
# Generating a column named side effect

mapping = {1: 5, 2: 4, 3: 3, 4: 2, 5: 1}
ldata['Sideeffect'] = ldata['Satisfaction'].map(mapping)

# %%
# Correlation plot using Heatmap

def plot_corr(ldata):
    corr = ldata.corr()
    sns.set_theme()
    plt.figure(figsize = (15,6))
    sns.heatmap(corr, cbar=True, annot=True, cmap='CMRmap')
plot_corr(ldata)

# %%
# plotting box plot for Outlier Handling

for i in ["EaseofUse","Effectiveness","Satisfaction","UsefulCount"]:
    plt.figure(figsize=(2,3))
    plt.title(i)
    plt.boxplot(ldata[i])

# %%
# Removing  Outlier from Usefulcount Using IQR

Q1 = ldata.UsefulCount.quantile(0.25)
Q3 = ldata.UsefulCount.quantile(0.75)
IQR = Q3 - Q1
min_limit = Q1 - (IQR * 1.5)
max_limit = Q3 + (IQR * 1.5)
print(min_limit, max_limit,IQR)
# Out:
# -10.5 25.5 9.0

# %%
ldata.loc[ldata['UsefulCount']>max_limit,'UsefulCount']=24

# %%
plt.boxplot(ldata["UsefulCount"]);

# %%
ldata.head(3)
# Out:
#         Name      Race         Age            Condition        Date  \
# 9203  Hector     Asian  75 or over  High Blood Pressure    2/8/2020
# 9209  Donnie  Hispanic       55-64  High Blood Pressure   1/14/2020
# 9215  Indira     Black       65-74  High Blood Pressure  10/17/2019
#
#                      Drug  DrugId  EaseofUse  Effectiveness  \
# 9203  lisinopril solution  6873.0        5.0            4.0
# 9209  lisinopril solution  6873.0        4.0            5.0
# 9215  lisinopril solution  6873.0        5.0            5.0
#
#                                                 Reviews  Satisfaction     Sex  \
# 9203  I have developed a very itch rash on my body f...           4.0  Female
# 9209  tried alternative medicine Beet root, hibiscus...           4.0    Male
# 9215  Have been taking 10 mg doses per day for over ...           5.0    Male
#
#                                                   Sides  UsefulCount    Year  \
# 9203  Dizziness ,  lightheadedness , tiredness, or  ...          3.0  2020.0
# 9209  Dizziness ,  lightheadedness , tiredness, or  ...          3.0  2020.0
# 9215  Dizziness ,  lightheadedness , tiredness, or  ...          6.0  2019.0
#
#       Sideeffect
# 9203           2
# 9209           2
# 9215           1

# %% [markdown]
# ## Cleaning Review column

# %% [markdown]
# Training an algoithm on the parent dataset which will clean the review column. The algorithm will get trained on satisfaction and reviews, which means, it will identify which reviews or specifically word consitutes positive review ( satisfaction > 3) and which one consitute negative reviews (satisfaction < 3)Rank the reviews as either positive or negative.Review rank for entries where satisfaction > 3 is 1 and for satisfaction < 3 is 0.

# %%
pip install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spacy in c:\users\chand\appdata\roaming\python\python39\site-packages (3.5.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\chand\appdata\roaming\python\python39\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\chand\appdata\roaming\python\python39\site-packages (from spacy) (1.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\chand\appdata\roaming\python\python39\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\chand\appdata\roaming\python\python39\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\chand\appdata\roaming\python\python39\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\chand\appdata\roaming\python\python39\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\programdata\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\chand\appdata\roaming\python\python39\site-packages (from spacy) (0.10.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\chand\appdata\roaming\python\python39\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\chand\appdata\roaming\python\python39\site-packages (from spacy) (1.10.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\chand\appdata\roaming\python\python39\site-packages (from spacy) (2.4.6)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\chand\appdata\roaming\python\python39\site-packages (from spacy) (8.1.10)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from spacy) (63.4.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\chand\appdata\roaming\python\python39\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: numpy>=1.15.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (1.21.5)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\chand\appdata\roaming\python\python39\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.14)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\chand\appdata\roaming\python\python39\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\chand\appdata\roaming\python\python39\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: colorama in c:\users\chand\appdata\roaming\python\python39\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\programdata\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2->spacy) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Removing any leading and trailing white spaces

if data['Reviews'].dtype.kind == "O":
        data['Reviews'] = data['Reviews'].str.strip()

# %%
data['Reviews']= data['Reviews'].astype(str)

# %%
# importing the trained pipeline for processing the texts

from spacy.cli import download as spacy_download
spacy_download("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# importing stop words from sklearn

nlp = spacy.load("en_core_web_sm", disable=["ner", "parser"])
STOPWORDS = set(sklearn_stop_words).union(set(stopwords.words("english")))

# %%
# defining a function called clean review which clean the reveiw column

def clean_review(text, STOPWORDS=STOPWORDS, nlp=nlp):
    """Cleans up text"""
    
    def rep_emo(text, placeholder_pos=' happyemoticon ', placeholder_neg=' sademoticon '):
        """Replace emoticons"""
        
        emoticons_pos = [":)", ":-)", ":p", ":-p", ":P", ":-P", ":D",":-D", ":]", ":-]", ";)", ";-)",
                         ";p", ";-p", ";P", ";-P", ";D", ";-D", ";]", ";-]", "=)", "=-)", "<3"]
        emoticons_neg = [":o", ":-o", ":O", ":-O", ":(", ":-(", ":c", ":-c", ":C", ":-C", ":[", ":-[",
                         ":/", ":-/", ":\\", ":-\\", ":n", ":-n", ":u", ":-u", "=(", "=-(", ":$", ":-$"]
        for e in emoticons_pos:
            text = text.replace(e, placeholder_pos)

        for e in emoticons_neg:
                text = text.replace(e, placeholder_neg)   
        return text

    def rep_punct(text):
        """Replace all punctuation with space"""
        for c in string.punctuation:
            text = text.replace(c, " ")
        return text

    def rem_stop_num(text):
        """Remove stop words and anything starting with number"""
        return " ".join(word for word in text.split() if word not in STOPWORDS and not word[0].isdigit())

    def lemmatize(text):
        """Return lemmas of tokens in text"""
        return " ".join(tok.lemma_.lower().strip() for tok in nlp(text) if tok.lemma_ != "-PRON-")  

    return lemmatize(rem_stop_num(rep_punct(rep_emo(text))))

# %%
# %%time
data3 = data[["Satisfaction", "Reviews"]]
data3["Reviews"] = data3["Reviews"].apply(clean_review)
data3["Reviews"].replace("", np.nan, inplace=True)
data3.dropna(inplace=True)
# Out:
# Wall time: 34min 39s

# %% [markdown]
# review column is cleaned now. generate a new column satisfaction1

# %%
def relabel(x):
    return 0 if x < 3 else 1 if x == 3 else 2

# %%
data3["Satisfaction1"] = data3["Satisfaction"].apply(relabel)

# %% [markdown]
# Fitting a model for processing text

# %%
train_set, test_set = train_test_split(data3, test_size=0.25, random_state=0, stratify=data3["Satisfaction1"])
train_index = train_set.index
test_index = test_set.index

# %%
# %%time
train_set = train_set[train_set["Satisfaction1"] != 1]
test_set = test_set[test_set["Satisfaction1"] != 1]

vectorizer = TfidfVectorizer(max_features=3000, min_df=10, max_df=0.8)
X_train = vectorizer.fit_transform(train_set["Reviews"]).toarray()
X_test = vectorizer.transform(test_set["Reviews"]).toarray()
y_train = train_set["Satisfaction1"].values
y_test = test_set["Satisfaction1"].values

model = RandomForestClassifier(min_samples_split=6, random_state=0)
model.fit(X_train, y_train)
# Out:
# Wall time: 58min 53s
# RandomForestClassifier(min_samples_split=6, random_state=0)

# %%
acc_train = accuracy_score(y_train, model.predict(X_train))
print(f"\nAccuracy in train set: {acc_train:.2}")
predictions = model.predict(X_test)
acc_test = accuracy_score(y_test, predictions)
print(f"\nAccuracy in test  set: {acc_test:.2}\n")
print(classification_report(y_test, predictions))
# Out:
# Accuracy in train set: 0.94
#
# Accuracy in test  set: 0.8
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78     36120
#            2       0.79      0.86      0.82     41166
#
#     accuracy                           0.80     77286
#    macro avg       0.80      0.80      0.80     77286
# weighted avg       0.80      0.80      0.80     77286

# %% [markdown]
# got an accuracy of 80% in test and 99 % in train now cleaning the review column of lisino pril solution

# %%
ldata["Reviews"] =ldata["Reviews"].astype(str)

# %%
ldata["Reviews"] = ldata["Reviews"].apply(clean_review)

# %% [markdown]
# generating rank column

# %%
# defining a function which assigns ranks 0 and 1

def predict_rank(text):
    cleaned_text = [clean_review(text)]
    padded_text = vectorizer.transform(cleaned_text)
    p = model.predict(padded_text)[0]
    if (p == 0):
        return 0
    else :
        return 1
    
def predict_rank1(rank):
    if (rank < 3):
        return 0
    else:
        return 1

# %%
ldata['Reviews_Rank'] = ldata['Satisfaction']
ldata.loc[ldata['Satisfaction'] < 3, 'Reviews_Rank'] = ldata.loc[ldata['Satisfaction'] < 3, 'Reviews_Rank'].apply(predict_rank1)
ldata.loc[ldata['Satisfaction'] > 3, 'Reviews_Rank'] = ldata.loc[ldata['Satisfaction'] > 3, 'Reviews_Rank'].apply(predict_rank1)
ldata.loc[ldata['Satisfaction'] == 3, 'Reviews_Rank'] = ldata.loc[ldata['Satisfaction'] == 3, 'Reviews'].apply(predict_rank)
ldata['Reviews_Rank'].unique()
# Out:
# array([1., 0.])

# %%
ldata = ldata.dropna()

# %%
df = ldata.copy()

# %%
df.to_excel("cleaneeeeee_data.xlsx")

# %%
# Removing unvanted columns and columns having unique values.name,drug, drug id,condition,date,ease of use,useful count,sides,year

ldata.drop(['Name','Condition','Drug','DrugId','Date','Sides','UsefulCount','EaseofUse','Reviews'], axis=1, inplace = True)

# %%
ldata.head(3)
# Out:
#           Race         Age  Effectiveness  Satisfaction     Sex    Year  \
# 9203     Asian  75 or over            4.0           4.0  Female  2020.0
# 9209  Hispanic       55-64            5.0           4.0    Male  2020.0
# 9215     Black       65-74            5.0           5.0    Male  2019.0
#
#       Sideeffect  Reviews_Rank
# 9203           2           1.0
# 9209           2           1.0
# 9215           1           1.0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
ldata["Race"] =le.fit_transform(ldata["Race"])
le1 = LabelEncoder()
ldata["Sex"] =le1.fit_transform(ldata["Sex"])
le2 = LabelEncoder()
ldata["Age"] =le2.fit_transform(ldata["Age"])
ldata
# Out:
#         Race  Age  Effectiveness  Satisfaction  Sex    Year  Sideeffect  \
# 9203       0    8       0.597853      0.846772    0  2020.0           2
# 9209       2    6       1.300289      0.846772    1  2020.0           2
# 9215       1    7       1.300289      1.513947    1  2019.0           1
# 9221       3    6       0.597853     -0.487576    1  2019.0           4
# 9227       2    6      -1.509455     -1.154750    0  2019.0           5
# ...      ...  ...            ...           ...  ...     ...         ...
# 402741     0    6      -0.807019      0.179598    0  2006.0           3
# 402748     3    6      -1.509455      1.513947    0  2014.0           1
# 402766     2    5       1.300289     -0.487576    0  2004.0           4
# 402782     2    6      -1.509455      0.846772    1  2005.0           2
# 402805     1    6       0.597853     -1.154750    1  2006.0           5
#
#         Reviews_Rank
# 9203             1.0
# 9209             1.0
# 9215             1.0
# 9221             0.0
# 9227             0.0
# ...              ...
# 402741           1.0
# 402748           1.0
# 402766           0.0
# 402782           1.0
# 402805           0.0
#
# [6018 rows x 8 columns]

# %%
ldata1 = ldata.copy()

# %%
# Pickling label encoder race

le_pkl = open('le.pkl','wb')
pickle.dump(le,le_pkl)
le_pkl.close()

# %%
# Pickling label encoder sex

le1_pkl = open('le1.pkl','wb')
pickle.dump(le1,le1_pkl)
le1_pkl.close()

# %%
# Pickling label encoder age

le2_pkl = open('le2.pkl','wb')
pickle.dump(le2,le2_pkl)
le2_pkl.close()

# %%
# Scaling Effectiveness and easeof use using standard scalar
std = StandardScaler()
ldata[["Effectiveness"]] = std.fit_transform(ldata[["Effectiveness"]])
std1 = StandardScaler()
ldata[["Satisfaction"]] = std1.fit_transform(ldata[["Satisfaction"]])
ldata.head(5)
# Out:
#       Race  Age  Effectiveness  Satisfaction  Sex    Year  Sideeffect  \
# 9203     0    8       0.597853      0.846772    0  2020.0           2
# 9209     2    6       1.300289      0.846772    1  2020.0           2
# 9215     1    7       1.300289      1.513947    1  2019.0           1
# 9221     3    6       0.597853     -0.487576    1  2019.0           4
# 9227     2    6      -1.509455     -1.154750    0  2019.0           5
#
#       Reviews_Rank
# 9203           1.0
# 9209           1.0
# 9215           1.0
# 9221           0.0
# 9227           0.0

# %%
# Pickling standard scalar for effectiveness

std_pkl = open('std.pkl','wb')
pickle.dump(std,std_pkl)
std_pkl.close()

# %%
# Pickling standard scalar satisfaction

std1_pkl = open('std1.pkl','wb')
pickle.dump(std1,std1_pkl)
std1_pkl.close()

# %%
final_data = ldata.copy()

# %% [raw]
#  #exporting the processed data set into a excel sheet for modeling
# ldata.to_excel("modeling_data.xlsx")

# %% [markdown]
# ## MODELING

# %%
#splitting into dependant and independent variables
x1 = final_data.drop(["Sideeffect"],axis = 1)
y1 = final_data["Sideeffect"]

# %%
# spliting into training and testing 

from sklearn.model_selection import train_test_split
x_train1,x_test1,y_train1,y_test1=train_test_split(x1,y1,random_state = 42,test_size=0.2)

# %%
# Importing required packeges for classification models

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
models = [['LogisticRegression :', LogisticRegression()],
          ['DecisionTreeClassifier :', DecisionTreeClassifier()],
          ['RandomForestClassifier :', RandomForestClassifier()],
          ['GradientBoostingClassifier   :', GradientBoostingClassifier()],
          ['KNeighborsClassifier :', KNeighborsClassifier()],
          ['SVC :', SVC()]]

# %%
for name, model in models:
    model = model
    model.fit(x_train1,y_train1)
    y_train_pred = model.predict(x_test1)
    print(name, accuracy_score(y_test1, y_train_pred))    
    print('Accuracy =',accuracy_score(y_test1,y_train_pred))
    print('Precision =',precision_score(y_test1,y_train_pred,average='micro'))
    print('Recall =',recall_score(y_test1,y_train_pred,average='micro'))
    print('F1 Score =',f1_score(y_test1,y_train_pred,average='micro'))
# Out:
# LogisticRegression : 0.9501661129568106
# Accuracy = 0.9501661129568106
# Precision = 0.9501661129568106
# Recall = 0.9501661129568106
# F1 Score = 0.9501661129568106
# DecisionTreeClassifier : 1.0
# Accuracy = 1.0
# Precision = 1.0
# Recall = 1.0
# F1 Score = 1.0
# RandomForestClassifier : 1.0
# Accuracy = 1.0
# Precision = 1.0
# Recall = 1.0
# F1 Score = 1.0
# GradientBoostingClassifier   : 1.0
# Accuracy = 1.0
# Precision = 1.0
# Recall = 1.0
# F1 Score = 1.0
# KNeighborsClassifier : 0.675249169435216
# Accuracy = 0.675249169435216
# Precision = 0.675249169435216
# Recall = 0.675249169435216
# F1 Score = 0.675249169435216
# SVC : 0.313953488372093
# Accuracy = 0.313953488372093
# Precision = 0.313953488372093
# Recall = 0.313953488372093
# F1 Score = 0.313953488372093

# %% [markdown]
# Random Forest Classifier gave an accuracy of 100%. Hence, this model is selected

# %%
# Random Forest Model
rm = RandomForestClassifier(random_state = 42)
rm_model = rm.fit(x_train1,y_train1)
rm_pred = rm_model.predict(x_test1)

# %%
# Metrics
print(confusion_matrix(y_test1, rm_pred))
print(accuracy_score(y_test1, rm_pred))
# Out:
# [[221   0   0   0   0]
#  [  0 201   0   0   0]
#  [  0   0 223   0   0]
#  [  0   0   0 181   0]
#  [  0   0   0   0 378]]
# 1.0

# %%
#CLassification Report
from sklearn.metrics import classification_report
report = classification_report(y_test1, rm_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00       221
#            2       1.00      1.00      1.00       201
#            3       1.00      1.00      1.00       223
#            4       1.00      1.00      1.00       181
#            5       1.00      1.00      1.00       378
#
#     accuracy                           1.00      1204
#    macro avg       1.00      1.00      1.00      1204
# weighted avg       1.00      1.00      1.00      1204

# %%
# pickling model

rmmodel_pkl = open('rmmodel.pkl','wb')
pickle.dump(rm,rmmodel_pkl)
rmmodel_pkl.close()

# %% [markdown]
# # Hyper Parametric Tuning (kNN-model)

# %%
# Hyper parametric Tuning of kNN model using Grid search

# %%
from sklearn.model_selection import GridSearchCV

# %%
# We will use three hyperparamters- n-neighbors, weights and metric.
grid_params = {'n_neighbors' : [5,7,9,11,13,15],
               'weights' : ['uniform','distance'],
               'metric' : ['minkowski','euclidean','manhattan']}

# %%
gs = GridSearchCV(KNeighborsClassifier(), grid_params, verbose = 1, cv=50, n_jobs = -1)

# %%
g_res = gs.fit(x_train1, y_train1)
# Out:
# Fitting 50 folds for each of 36 candidates, totalling 1800 fits

# %%
# Bestscore
g_res.best_score_
# Out:
# 0.9196155498281786

# %%
 #get the hyperparameters with the best score
g_res.best_params_
# Out:
# {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'distance'}

# %%
# use the best hyperparameters
knn = KNeighborsClassifier(n_neighbors = 15, weights = 'distance',algorithm = 'brute',metric = 'manhattan')
knn.fit(x_train1, y_train1)
# Out:
# KNeighborsClassifier(algorithm='brute', metric='manhattan', n_neighbors=15,
#                      weights='distance')

# %%
y_hat = knn.predict(x_train1)
y_knn = knn.predict(x_test1)

# %%
from sklearn import metrics

# %%
print('Training set accuracy: ', metrics.accuracy_score(y_train1, y_hat))
print('Test set accuracy: ',metrics.accuracy_score(y_test1, y_knn))
# Out:
# Training set accuracy:  1.0
# Test set accuracy:  0.925249169435216

# %% [markdown]
# As we see, we have obtained a very high model accuracy of 0.99 in kNN classifier
